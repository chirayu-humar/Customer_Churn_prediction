# %%
import sys
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  C:\Users\dell\anaconda3

# %%
import warnings
warnings.filterwarnings('ignore')

# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score

# %%
# data import
churn_data = pd.read_csv('churn_data.csv')
cust_data = pd.read_csv('customer_data.csv')
internet_data = pd.read_csv('internet_data.csv')

# data dimensions
print(f'Churn data has {churn_data.shape[0]} rows and {churn_data.shape[1]} columns.')
print(f'Customer data has {cust_data.shape[0]} rows and {cust_data.shape[1]} columns.')
print(f'Internet data has {internet_data.shape[0]} rows and {internet_data.shape[1]} columns.')
# Out:
# Churn data has 7043 rows and 9 columns.
# Customer data has 7043 rows and 5 columns.
# Internet data has 7043 rows and 9 columns.

# %%
# columns of the datas
for data in [churn_data, cust_data, internet_data]:
    print(list(data.columns))
# Out:
# ['customerID', 'tenure', 'PhoneService', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents']
# ['customerID', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
# data merge
data = pd.merge(churn_data, cust_data, how='inner', on='customerID')
data = pd.merge(data, internet_data, how='inner', on='customerID')

# merged data sample
data.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn  gender  ...  \
# 0           Electronic check           29.85        29.85    No  Female  ...
# 1               Mailed check           56.95       1889.5    No    Male  ...
# 2               Mailed check           53.85       108.15   Yes    Male  ...
# 3  Bank transfer (automatic)           42.30      1840.75    No    Male  ...
# 4           Electronic check           70.70       151.65   Yes  Female  ...
#
#    Partner Dependents     MultipleLines InternetService OnlineSecurity  \
# ...

# %%
# Data types of the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   Churn             7043 non-null   object
#  9   gender            7043 non-null   object
#  10  SeniorCitizen     7043 non-null   int64
#  11  Partner           7043 non-null   object
#  12  Dependents        7043 non-null   object
#  13  MultipleLines     7043 non-null   object
#  14  InternetService   7043 non-null   object
#  15  OnlineSecurity    7043 non-null   object
# ...

# %%
# Analysing the 'TotalCharges' column
data['TotalCharges'].value_counts()
# Out:
# TotalCharges
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: count, Length: 6531, dtype: int64

# %%
# Replacing the empty string columns to nan
data['TotalCharges'] = np.where(data['TotalCharges']==' ', np.nan, data['TotalCharges'])

# Type casting the data
data['TotalCharges'] = data['TotalCharges'].astype('float')
print(data['TotalCharges'].dtype)
# Out:
# float64

# %%
# Null value check
data.isnull().sum()
# Out:
# customerID           0
# tenure               0
# PhoneService         0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# dtype: int64

# %%
# analysing the 'TotalCharges' to fix the missing values
sns.boxplot(data['TotalCharges'], orient='h')
plt.show()

# %%
# the data seems to skewed, so replace the missing value with median
data['TotalCharges'].fillna(data['TotalCharges'].median(), inplace=True)

# %%
# ploting the target variable
ax = sns.countplot(x = data['Churn'], color='purple')
plt.bar_label(ax.containers[0])
plt.title('TARGET VARIABLE DISTRIBUTION')
plt.show()

# %%
# Creating the list of categorical and numerical columns
cat_cols = [cols for cols in data.columns if data[cols].dtype == 'O']
num_cols = [cols for cols in data.columns if cols not in cat_cols]

# %%
# Analysing the categorical variables
plot_cols = [cols for cols in cat_cols if cols not in ['customerID', 'Churn']]

# Set up the subplot grid
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(28, 30))

# %%
# Analysing the categorical variables
plot_cols = [cols for cols in cat_cols if cols not in ['customerID', 'Churn']]

# Set up the subplot grid
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(28, 30))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Iterate over the columns and plot a countplot on each subplot
for i, cols in enumerate(plot_cols):
    ax = axes[i]
    grp = sns.countplot(x = data[cols], ax=ax, order=data[cols].value_counts().index, color='purple')
    ax.set_title(cols)
    ax.bar_label(grp.containers[0])

plt.tight_layout()
plt.show()

# %%
# Set up the subplot grid
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(7, 3))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Iterate over the columns and plot a boxplot on each subplot
for i, cols in enumerate(['MonthlyCharges', 'TotalCharges']):
    ax = axes[i]
    grp = sns.boxplot(data[cols], ax=ax, orient='h')
    ax.set_title(cols)

plt.tight_layout()
plt.show()

# %%
# Analysing the categorical variables
plot_cols = [cols for cols in cat_cols if cols not in['customerID', 'Churn']]

# Set up the subplot grid
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(28, 30))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Iterate over the columns and plot a boxplot on each subplot
for i, cols in enumerate(plot_cols):
    ax = axes[i]
    grp = sns.countplot(x = data[cols], ax=ax,
                        order=data[cols].value_counts().index,
                        hue=data['Churn'])
    ax.set_title(cols)
    ax.bar_label(grp.containers[0])
    ax.bar_label(grp.containers[1])

plt.tight_layout()
plt.show()

# %%
x=np.array([[2,3],[5,2],[6,7]])
x
# Out:
# array([[2, 3],
#        [5, 2],
#        [6, 7]])

# %%
x.flatten()
# Out:
# array([2, 3, 5, 2, 6, 7])

# %%
# Removing the "customerID" column as it doesn't contribute to the analysis
data.drop(['customerID'], axis=1, inplace=True)

# %%
# data sample
data.head()
# Out:
#    tenure PhoneService        Contract PaperlessBilling  \
# 0       1           No  Month-to-month              Yes
# 1      34          Yes        One year               No
# 2       2          Yes  Month-to-month              Yes
# 3      45           No        One year               No
# 4       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges Churn  gender  \
# 0           Electronic check           29.85         29.85    No  Female
# 1               Mailed check           56.95       1889.50    No    Male
# 2               Mailed check           53.85        108.15   Yes    Male
# 3  Bank transfer (automatic)           42.30       1840.75    No    Male
# 4           Electronic check           70.70        151.65   Yes  Female
#
#    SeniorCitizen Partner Dependents     MultipleLines InternetService  \
# 0              0     Yes         No  No phone service             DSL
# ...

# %%
# One hot encoding the categorical variable
encoded_data = pd.get_dummies(data, drop_first=True, dtype='int')
encoded_data.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  SeniorCitizen  PhoneService_Yes  \
# 0       1           29.85         29.85              0                 0
# 1      34           56.95       1889.50              0                 1
# 2       2           53.85        108.15              0                 1
# 3      45           42.30       1840.75              0                 0
# 4       2           70.70        151.65              0                 1
#
#    Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0                  0                  0                     1
# 1                  1                  0                     0
# 2                  0                  0                     1
# 3                  1                  0                     0
# 4                  0                  0                     1
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  ...  \
# ...

# %%
# Multicollinearity Check
plt.figure(figsize=(20,18))
sns.heatmap(encoded_data.corr(), annot=True, fmt='.2f', vmin=-1, vmax=1)
plt.show()

# %%
# predictor and target data split
x = encoded_data.drop(['Churn_Yes'], axis=1)
y = encoded_data['Churn_Yes']

# train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=57)

# %%
# Data standardisation

scale= StandardScaler()
x_train = scale.fit_transform(x_train)
x_test= scale.transform(x_test)

# %%
# random Forest
from sklearn.ensemble import RandomForestClassifier

# Initializing and training Random Forest Classifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predictions on testing data
rf_pred = rf_classifier.predict(x_test)

# Evaluating Random Forest Classifier
accuracy = rf_classifier.score(x_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7898722195929957

# %%
# Metrics
cm = ConfusionMatrixDisplay.from_predictions(y_test, rf_pred)
report = classification_report(y_test, rf_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1540
#            1       0.64      0.50      0.57       573
#
#     accuracy                           0.79      2113
#    macro avg       0.74      0.70      0.71      2113
# weighted avg       0.78      0.79      0.78      2113

# %%
# Variable Importance
# Getting feature importances from the trained Random Forest model
feature_importances = rf_classifier.feature_importances_

# Mapping feature importance values to corresponding feature names
feature_names = pd.DataFrame(x.columns, columns=['Feature'])
feature_importance_df = pd.DataFrame(feature_importances, columns=['Importance'])
feature_importance_df = pd.concat([feature_names, feature_importance_df], axis=1)

# Sorting features based on importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)


feature_importance_df
# Out:
#                                   Feature  Importance
# 2                            TotalCharges    0.202064
# 1                          MonthlyCharges    0.166750
# 0                                  tenure    0.164591
# 9          PaymentMethod_Electronic check    0.037659
# 16            InternetService_Fiber optic    0.035108
# 6                       Contract_Two year    0.030337
# 11                            gender_Male    0.029074
# 19                     OnlineSecurity_Yes    0.026918
# 7                    PaperlessBilling_Yes    0.026040
# 25                        TechSupport_Yes    0.024157
# 12                            Partner_Yes    0.023982
# 5                       Contract_One year    0.023508
# 21                       OnlineBackup_Yes    0.021771
# 3                           SeniorCitizen    0.020778
# 13                         Dependents_Yes    0.020277
# 15                      MultipleLines_Yes    0.019982
# ...

# %%
# Plotting Variable Importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Variable Importance')
plt.gca().invert_yaxis()  # Invert y-axis to display most important features at the top
plt.show()

# %%
# Select the top 15 features based on their importance
top_features = feature_importance_df['Feature'][:15].tolist()
top_features
# Out:
# ['TotalCharges',
#  'MonthlyCharges',
#  'tenure',
#  'PaymentMethod_Electronic check',
#  'InternetService_Fiber optic',
#  'Contract_Two year',
#  'gender_Male',
#  'OnlineSecurity_Yes',
#  'PaperlessBilling_Yes',
#  'TechSupport_Yes',
#  'Partner_Yes',
#  'Contract_One year',
#  'OnlineBackup_Yes',
#  'SeniorCitizen',
#  'Dependents_Yes']

# %%
x = encoded_data[top_features]
y = encoded_data['Churn_Yes']

# train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=57)

# %%
import imblearn
import sklearn
print(imblearn.__version__)
print(sklearn.__version__)
# Out:
# 0.12.2
# 1.2.2

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  C:\Users\dell\anaconda3

# %%
# Balancing the data - synthetic minority over sampling technique
from imblearn.over_sampling import SMOTE

# SMOTE to balance the data
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Check the balanced class distribution
print(y_train_balanced.value_counts())
# Out:
# Churn_Yes
# 0    4144
# 1    4144
# Name: count, dtype: int64

# %%
# Data standardisation

scale= StandardScaler()
x_train = scale.fit_transform(x_train)
x_test= scale.transform(x_test)

# %%
# Define the parameter grid for GridSearchCV
param_grid = {'max_depth':[2,3,4,6,8,10,15],
           'max_features':['auto','sqrt','log2'],
           'criterion':['gini','entropy'],
           'n_estimators':[7,11,15,21,27,31]}

# Initialize Random Forest Classifier
rf_classifier = RandomForestClassifier(random_state=42)

# Perform GridSearchCV
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train_balanced, y_train_balanced)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'auto', 'n_estimators': 31}
# Best Score: 0.8254224320115778

# %%
y_pred=grid_search.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.772888573456352

# %%
# Train the Random Forest model using the best parameters
best_rf_classifier = RandomForestClassifier(n_estimators= 31, max_depth= 15, max_features='sqrt',criterion='gini', random_state=42)
best_rf_classifier.fit(x_train_balanced, y_train_balanced)

# Make predictions on the test set
predictions = best_rf_classifier.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print("Test Accuracy:", accuracy)

# Classification report
report = classification_report(y_test, predictions)
print(report)

# Confusion Matrix
cm = ConfusionMatrixDisplay.from_predictions(y_test, predictions)
# Out:
# Test Accuracy: 0.7629524485450674
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83      1030
#            1       0.55      0.65      0.60       379
#
#     accuracy                           0.76      1409
#    macro avg       0.71      0.73      0.71      1409
# weighted avg       0.78      0.76      0.77      1409

# %%
from sklearn.tree import DecisionTreeClassifier

# Define the parameter grid for GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [ 10, 20, 30, 40, 50, 60],
    'min_samples_split': [2, 5, 10, 15],
    'min_samples_leaf': [1, 2, 4, 8]
}

# Initialize Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)


# Perform GridSearchCV
grid_search = GridSearchCV(estimator=dt_classifier, param_grid=param_grid, cv=5, scoring='precision', n_jobs=-1)
grid_search.fit(x_train_balanced, y_train_balanced)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# %%
y_pred=grid_search.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy

# %%
# Make predictions on the test set
predictions = grid_search.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print("Test Accuracy:", accuracy)

# Classification report
report = classification_report(y_test, predictions)
print(report)

# Confusion Matrix
cm = ConfusionMatrixDisplay.from_predictions(y_test, predictions)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize KNN classifier
knn_classifier = KNeighborsClassifier()

# Define hyperparameters and their values for GridSearchCV
param_grid = {
    'n_neighbors': [3, 5, 7, 9],  # Number of neighbors
    'metric': ['euclidean', 'manhattan']  # Distance metric
}

# Perform GridSearchCV
grid_search = GridSearchCV(estimator=knn_classifier, param_grid=param_grid, cv=5, scoring='recall', n_jobs=-1)
grid_search.fit(x_train_balanced, y_train_balanced)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# %%
# Make predictions on the test set
predictions = grid_search.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print("Test Accuracy:", accuracy)

# Classification report
report = classification_report(y_test, predictions)
print(report)

# Confusion Matrix
cm = ConfusionMatrixDisplay.from_predictions(y_test, predictions)

# %%
top_features

# %%
# Multicollinearity Check
plt.figure(figsize=(20,18))
sns.heatmap(encoded_data[top_features].corr(), annot=True, fmt='.2f', vmin=-1, vmax=1)
plt.show()

# %%
# Further more hyper parameter tuning can be performed to improve the performance of the model
